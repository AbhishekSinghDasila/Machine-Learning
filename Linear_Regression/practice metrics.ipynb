# %%
import numpy as np

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
x=np.array([50,80,100,120,150,180,200,220]).reshape(-1,1)

# %%
y=np.array([100,160,200,240,300,360,400,500])

# %%
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x)

# %%
mae=mean_absolute_error(y,y_pred)
mse=mean_squared_error(y,y_pred)
rmse=np.sqrt(mse)

# %%
r2=r2_score(y,y_pred)
adj_r2=1-((1-r2)*(len(y)-1)/(len(y)-1-x.shape[1]))

# %%
print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2:", r2)
print("Adjusted R2:", adj_r2)
# Out:
# MAE: 12.42603550295857
# MSE: 272.92899408284023
# RMSE: 16.520562765318868
# R2: 0.9824412388205651
# Adjusted R2: 0.9795147786239926
